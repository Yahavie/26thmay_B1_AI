# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
# %matplotlib inline
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("train.csv") 
df
# Out:
#       Id   Open Date        City  City Group Type  P1   P2   P3   P4  P5  ...  \
# 0      0  07/17/1999    İstanbul  Big Cities   IL   4  5.0  4.0  4.0   2  ...
# 1      1  02/14/2008      Ankara  Big Cities   FC   4  5.0  4.0  4.0   1  ...
# 2      2  03/09/2013  Diyarbakır       Other   IL   2  4.0  2.0  5.0   2  ...
# 3      3  02/02/2012       Tokat       Other   IL   6  4.5  6.0  6.0   4  ...
# 4      4  05/09/2009   Gaziantep       Other   IL   3  4.0  3.0  4.0   2  ...
# ..   ...         ...         ...         ...  ...  ..  ...  ...  ...  ..  ...
# 132  132  06/25/2008     Trabzon       Other   FC   2  3.0  3.0  5.0   4  ...
# 133  133  10/12/2006       İzmir  Big Cities   FC   4  5.0  4.0  4.0   2  ...
# 134  134  07/08/2006     Kayseri       Other   FC   3  4.0  4.0  4.0   2  ...
# 135  135  10/29/2010    İstanbul  Big Cities   FC   4  5.0  4.0  5.0   2  ...
# 136  136  09/01/2009    İstanbul  Big Cities   FC   4  5.0  3.0  5.0   2  ...
#
# ...

# %%
df_test = pd.read_csv('test.csv')
df_test
# Out:
#           Id   Open Date            City  City Group Type  P1   P2   P3   P4  \
# 0          0  01/22/2011           Niğde       Other   FC   1  4.0  4.0  4.0
# 1          1  03/18/2011           Konya       Other   IL   3  4.0  4.0  4.0
# 2          2  10/30/2013          Ankara  Big Cities   FC   3  4.0  4.0  4.0
# 3          3  05/06/2013         Kocaeli       Other   IL   2  4.0  4.0  4.0
# 4          4  07/31/2013  Afyonkarahisar       Other   FC   2  4.0  4.0  4.0
# ...      ...         ...             ...         ...  ...  ..  ...  ...  ...
# 99995  99995  01/05/2000         Antalya       Other   FC   5  5.0  4.0  4.0
# 99996  99996  07/18/2011           Niğde       Other   IL   1  2.0  4.0  3.0
# 99997  99997  12/29/2012        İstanbul  Big Cities   IL   4  5.0  4.0  4.0
# 99998  99998  10/12/2013        İstanbul  Big Cities   FC  12  7.5  6.0  6.0
# 99999  99999  10/05/2010        İstanbul  Big Cities   IL   2  5.0  4.0  4.0
#
# ...

# %%
#DATA ANALYSIS AND VISUALIZATION

# %%
df.shape
# Out:
# (137, 43)

# %%
df.columns
# Out:
# Index(['Id', 'Open Date', 'City', 'City Group', 'Type', 'P1', 'P2', 'P3', 'P4',
#        'P5', 'P6', 'P7', 'P8', 'P9', 'P10', 'P11', 'P12', 'P13', 'P14', 'P15',
#        'P16', 'P17', 'P18', 'P19', 'P20', 'P21', 'P22', 'P23', 'P24', 'P25',
#        'P26', 'P27', 'P28', 'P29', 'P30', 'P31', 'P32', 'P33', 'P34', 'P35',
#        'P36', 'P37', 'revenue'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# Id            0
# Open Date     0
# City          0
# City Group    0
# Type          0
# P1            0
# P2            0
# P3            0
# P4            0
# P5            0
# P6            0
# P7            0
# P8            0
# P9            0
# P10           0
# P11           0
# P12           0
# P13           0
# P14           0
# P15           0
# P16           0
# P17           0
# P18           0
# P19           0
# P20           0
# P21           0
# P22           0
# P23           0
# P24           0
# P25           0
# P26           0
# P27           0
# P28           0
# P29           0
# P30           0
# P31           0
# P32           0
# P33           0
# P34           0
# P35           0
# P36           0
# P37           0
# revenue       0
# dtype: int64

# %%
#no Missing Value

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137 entries, 0 to 136
# Data columns (total 43 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Id          137 non-null    int64
#  1   Open Date   137 non-null    object
#  2   City        137 non-null    object
#  3   City Group  137 non-null    object
#  4   Type        137 non-null    object
#  5   P1          137 non-null    int64
#  6   P2          137 non-null    float64
#  7   P3          137 non-null    float64
#  8   P4          137 non-null    float64
#  9   P5          137 non-null    int64
#  10  P6          137 non-null    int64
#  11  P7          137 non-null    int64
#  12  P8          137 non-null    int64
#  13  P9          137 non-null    int64
#  14  P10         137 non-null    int64
#  15  P11         137 non-null    int64
#  16  P12         137 non-null    int64
#  17  P13         137 non-null    float64
#  18  P14         137 non-null    int64
# ...

# %%
df=df.drop('Id',axis=1)
df
# Out:
#       Open Date        City  City Group Type  P1   P2   P3   P4  P5  P6  ...  \
# 0    07/17/1999    İstanbul  Big Cities   IL   4  5.0  4.0  4.0   2   2  ...
# 1    02/14/2008      Ankara  Big Cities   FC   4  5.0  4.0  4.0   1   2  ...
# 2    03/09/2013  Diyarbakır       Other   IL   2  4.0  2.0  5.0   2   3  ...
# 3    02/02/2012       Tokat       Other   IL   6  4.5  6.0  6.0   4   4  ...
# 4    05/09/2009   Gaziantep       Other   IL   3  4.0  3.0  4.0   2   2  ...
# ..          ...         ...         ...  ...  ..  ...  ...  ...  ..  ..  ...
# 132  06/25/2008     Trabzon       Other   FC   2  3.0  3.0  5.0   4   2  ...
# 133  10/12/2006       İzmir  Big Cities   FC   4  5.0  4.0  4.0   2   3  ...
# 134  07/08/2006     Kayseri       Other   FC   3  4.0  4.0  4.0   2   3  ...
# 135  10/29/2010    İstanbul  Big Cities   FC   4  5.0  4.0  5.0   2   2  ...
# 136  09/01/2009    İstanbul  Big Cities   FC   4  5.0  3.0  5.0   2   2  ...
#
# ...

# %%
sns.countplot(df['City Group'])
# Out:
# <AxesSubplot:xlabel='City Group', ylabel='count'>

# %%
plt.figure(figsize = (15,7))
sns.countplot(df.City)
# Out:
# <AxesSubplot:xlabel='City', ylabel='count'>

# %%
#Unique values in Type

# %%
df.Type.unique()
# Out:
# array(['IL', 'FC', 'DT'], dtype=object)

# %%
#countplot for type

# %%
sns.countplot(df.Type)
# Out:
# <AxesSubplot:xlabel='Type', ylabel='count'>

# %%
#countplot for opendate

# %%
plt.figure(figsize = (15,7))
sns.countplot(df['Open Date'])
# Out:
# <AxesSubplot:xlabel='Open Date', ylabel='count'>

# %%
#convert the 'Open Date' feature in datetime format to extract the month and year as they can give an insight on revenue

# %%
df['Open Date'] = pd.to_datetime(df['Open Date'])
df
# Out:
#      Open Date        City  City Group Type  P1   P2   P3   P4  P5  P6  ...  \
# 0   1999-07-17    İstanbul  Big Cities   IL   4  5.0  4.0  4.0   2   2  ...
# 1   2008-02-14      Ankara  Big Cities   FC   4  5.0  4.0  4.0   1   2  ...
# 2   2013-03-09  Diyarbakır       Other   IL   2  4.0  2.0  5.0   2   3  ...
# 3   2012-02-02       Tokat       Other   IL   6  4.5  6.0  6.0   4   4  ...
# 4   2009-05-09   Gaziantep       Other   IL   3  4.0  3.0  4.0   2   2  ...
# ..         ...         ...         ...  ...  ..  ...  ...  ...  ..  ..  ...
# 132 2008-06-25     Trabzon       Other   FC   2  3.0  3.0  5.0   4   2  ...
# 133 2006-10-12       İzmir  Big Cities   FC   4  5.0  4.0  4.0   2   3  ...
# 134 2006-07-08     Kayseri       Other   FC   3  4.0  4.0  4.0   2   3  ...
# 135 2010-10-29    İstanbul  Big Cities   FC   4  5.0  4.0  5.0   2   2  ...
# 136 2009-09-01    İstanbul  Big Cities   FC   4  5.0  3.0  5.0   2   2  ...
#
# ...

# %%
df['month']=[x.month for x in df['Open Date']]

# %%
df['year']=[x.year for x in df['Open Date']]

# %%
df.columns
# Out:
# Index(['Open Date', 'City', 'City Group', 'Type', 'P1', 'P2', 'P3', 'P4', 'P5',
#        'P6', 'P7', 'P8', 'P9', 'P10', 'P11', 'P12', 'P13', 'P14', 'P15', 'P16',
#        'P17', 'P18', 'P19', 'P20', 'P21', 'P22', 'P23', 'P24', 'P25', 'P26',
#        'P27', 'P28', 'P29', 'P30', 'P31', 'P32', 'P33', 'P34', 'P35', 'P36',
#        'P37', 'revenue', 'month', 'year'],
#       dtype='object')

# %%
df=df.drop(['Open Date'],axis=1)
df
# Out:
#            City  City Group Type  P1   P2   P3   P4  P5  P6  P7  ...  P31  \
# 0      İstanbul  Big Cities   IL   4  5.0  4.0  4.0   2   2   5  ...    3
# 1        Ankara  Big Cities   FC   4  5.0  4.0  4.0   1   2   5  ...    0
# 2    Diyarbakır       Other   IL   2  4.0  2.0  5.0   2   3   5  ...    0
# 3         Tokat       Other   IL   6  4.5  6.0  6.0   4   4  10  ...   12
# 4     Gaziantep       Other   IL   3  4.0  3.0  4.0   2   2   5  ...    1
# ..          ...         ...  ...  ..  ...  ...  ...  ..  ..  ..  ...  ...
# 132     Trabzon       Other   FC   2  3.0  3.0  5.0   4   2   4  ...    0
# 133       İzmir  Big Cities   FC   4  5.0  4.0  4.0   2   3   5  ...    0
# 134     Kayseri       Other   FC   3  4.0  4.0  4.0   2   3   5  ...    0
# 135    İstanbul  Big Cities   FC   4  5.0  4.0  5.0   2   2   5  ...    0
# 136    İstanbul  Big Cities   FC   4  5.0  3.0  5.0   2   2   5  ...    0
#
#      P32  P33  P34  P35  P36  P37    revenue  month  year
# ...

# %%
sns.countplot(df['month'])
# Out:
# <AxesSubplot:xlabel='month', ylabel='count'>

# %%
plt.figure(figsize=(15,6))
sns.countplot(df['year'])
# Out:
# <AxesSubplot:xlabel='year', ylabel='count'>

# %%
df.groupby('month')['revenue'].mean()
# Out:
# month
# 1     5.900851e+06
# 2     4.189109e+06
# 3     3.969557e+06
# 4     4.726097e+06
# 5     3.657800e+06
# 6     3.776214e+06
# 7     3.458596e+06
# 8     3.883020e+06
# 9     5.390856e+06
# 10    5.236838e+06
# 11    4.721400e+06
# 12    4.299763e+06
# Name: revenue, dtype: float64

# %%
#Thus January gave the most revenue followed by September and October

# %%
#Plotting a bargraph with the obtained insight

# %%
sns.barplot('month','revenue',data=df)
# Out:
# <AxesSubplot:xlabel='month', ylabel='revenue'>

# %%
plt.figure(figsize=(15,6))
sns.countplot(df['year'])
# Out:
# <AxesSubplot:xlabel='year', ylabel='count'>

# %%
#From the above graph we can get that most of the data is from the years 2008-2013 and out of them 2011 has the greatest data.

# %%
df.groupby('year')['revenue'].mean()
# Out:
# year
# 1996    3.903884e+06
# 1997    4.286645e+06
# 1998    4.251905e+06
# 1999    7.329030e+06
# 2000    1.359602e+07
# 2002    4.991022e+06
# 2004    3.482435e+06
# 2005    6.611118e+06
# 2006    4.203972e+06
# 2007    5.079333e+06
# 2008    4.876962e+06
# 2009    4.652457e+06
# 2010    4.383878e+06
# 2011    4.147879e+06
# 2012    3.837859e+06
# 2013    2.532287e+06
# 2014    2.464944e+06
# Name: revenue, dtype: float64

# %%
plt.figure(figsize=(15,6))
sns.barplot('year','revenue',data=df)
# Out:
# <AxesSubplot:xlabel='year', ylabel='revenue'>

# %%
#Data preprocessing

# %%
df['Type'].value_counts()
# Out:
# FC    76
# IL    60
# DT     1
# Name: Type, dtype: int64

# %%
#FC as 0|IL as 1|DT as 2

# %%
ty={'FC':0,'IL':1,'DT':2}
df['Type'] = df['Type'].map(ty)
df
# Out:
#            City  City Group  Type  P1   P2   P3   P4  P5  P6  P7  ...  P31  \
# 0      İstanbul  Big Cities     1   4  5.0  4.0  4.0   2   2   5  ...    3
# 1        Ankara  Big Cities     0   4  5.0  4.0  4.0   1   2   5  ...    0
# 2    Diyarbakır       Other     1   2  4.0  2.0  5.0   2   3   5  ...    0
# 3         Tokat       Other     1   6  4.5  6.0  6.0   4   4  10  ...   12
# 4     Gaziantep       Other     1   3  4.0  3.0  4.0   2   2   5  ...    1
# ..          ...         ...   ...  ..  ...  ...  ...  ..  ..  ..  ...  ...
# 132     Trabzon       Other     0   2  3.0  3.0  5.0   4   2   4  ...    0
# 133       İzmir  Big Cities     0   4  5.0  4.0  4.0   2   3   5  ...    0
# 134     Kayseri       Other     0   3  4.0  4.0  4.0   2   3   5  ...    0
# 135    İstanbul  Big Cities     0   4  5.0  4.0  5.0   2   2   5  ...    0
# 136    İstanbul  Big Cities     0   4  5.0  3.0  5.0   2   2   5  ...    0
#
#      P32  P33  P34  P35  P36  P37    revenue  month  year
# ...

# %%
df['City Group'].value_counts()
# Out:
# Big Cities    78
# Other         59
# Name: City Group, dtype: int64

# %%
cg={'Big Cities':0,'Other':1}
df['City Group'] = df['City Group'].map(cg)
df
# Out:
#            City  City Group  Type  P1   P2   P3   P4  P5  P6  P7  ...  P31  \
# 0      İstanbul           0     1   4  5.0  4.0  4.0   2   2   5  ...    3
# 1        Ankara           0     0   4  5.0  4.0  4.0   1   2   5  ...    0
# 2    Diyarbakır           1     1   2  4.0  2.0  5.0   2   3   5  ...    0
# 3         Tokat           1     1   6  4.5  6.0  6.0   4   4  10  ...   12
# 4     Gaziantep           1     1   3  4.0  3.0  4.0   2   2   5  ...    1
# ..          ...         ...   ...  ..  ...  ...  ...  ..  ..  ..  ...  ...
# 132     Trabzon           1     0   2  3.0  3.0  5.0   4   2   4  ...    0
# 133       İzmir           0     0   4  5.0  4.0  4.0   2   3   5  ...    0
# 134     Kayseri           1     0   3  4.0  4.0  4.0   2   3   5  ...    0
# 135    İstanbul           0     0   4  5.0  4.0  5.0   2   2   5  ...    0
# 136    İstanbul           0     0   4  5.0  3.0  5.0   2   2   5  ...    0
#
#      P32  P33  P34  P35  P36  P37    revenue  month  year
# ...

# %%
#Saving names as list and using the element as key and index of each elements as keyvalues

# %%
a=df['City'].value_counts()
a
# Out:
# İstanbul          50
# Ankara            19
# İzmir              9
# Samsun             5
# Bursa              5
# Sakarya            4
# Antalya            4
# Eskişehir          3
# Tekirdağ           3
# Diyarbakır         3
# Kayseri            3
# Adana              3
# Konya              2
# Aydın              2
# Muğla              2
# Trabzon            2
# Kocaeli            1
# Bolu               1
# Gaziantep          1
# Uşak               1
# Kastamonu          1
# Balıkesir          1
# Amasya             1
# Karabük            1
# Şanlıurfa          1
# Elazığ             1
# Afyonkarahisar     1
# Kırklareli         1
# Denizli            1
# Edirne             1
# Isparta            1
# Kütahya            1
# Osmaniye           1
# Tokat              1
# Name: City, dtype: int64

# %%
b=a.index
b
# Out:
# Index(['İstanbul', 'Ankara', 'İzmir', 'Samsun', 'Bursa', 'Sakarya', 'Antalya',
#        'Eskişehir', 'Tekirdağ', 'Diyarbakır', 'Kayseri', 'Adana', 'Konya',
#        'Aydın', 'Muğla', 'Trabzon', 'Kocaeli', 'Bolu', 'Gaziantep', 'Uşak',
#        'Kastamonu', 'Balıkesir', 'Amasya', 'Karabük', 'Şanlıurfa', 'Elazığ',
#        'Afyonkarahisar', 'Kırklareli', 'Denizli', 'Edirne', 'Isparta',
#        'Kütahya', 'Osmaniye', 'Tokat'],
#       dtype='object')

# %%
c={}
for i,j in enumerate(b):
  c.update({j:i})
  print(c)
# Out:
# {'İstanbul': 0}
# {'İstanbul': 0, 'Ankara': 1}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Samsun': 3}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Samsun': 3, 'Bursa': 4}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Samsun': 3, 'Bursa': 4, 'Sakarya': 5}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Samsun': 3, 'Bursa': 4, 'Sakarya': 5, 'Antalya': 6}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Samsun': 3, 'Bursa': 4, 'Sakarya': 5, 'Antalya': 6, 'Eskişehir': 7}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Samsun': 3, 'Bursa': 4, 'Sakarya': 5, 'Antalya': 6, 'Eskişehir': 7, 'Tekirdağ': 8}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Samsun': 3, 'Bursa': 4, 'Sakarya': 5, 'Antalya': 6, 'Eskişehir': 7, 'Tekirdağ': 8, 'Diyarbakır': 9}
# {'İstanbul': 0, 'Ankara': 1, 'İzmir': 2, 'Samsun': 3, 'Bursa': 4, 'Sakarya': 5, 'Antalya': 6, 'Eskişehir': 7, 'Tekirdağ': 8, 'Diyarbakır': 9, 'Kayseri': 10}
# ...

# %%
c
# Out:
# {'İstanbul': 0,
#  'Ankara': 1,
#  'İzmir': 2,
#  'Samsun': 3,
#  'Bursa': 4,
#  'Sakarya': 5,
#  'Antalya': 6,
#  'Eskişehir': 7,
#  'Tekirdağ': 8,
#  'Diyarbakır': 9,
#  'Kayseri': 10,
#  'Adana': 11,
#  'Konya': 12,
#  'Aydın': 13,
#  'Muğla': 14,
#  'Trabzon': 15,
#  'Kocaeli': 16,
#  'Bolu': 17,
#  'Gaziantep': 18,
#  'Uşak': 19,
#  'Kastamonu': 20,
#  'Balıkesir': 21,
#  'Amasya': 22,
#  'Karabük': 23,
#  'Şanlıurfa': 24,
#  'Elazığ': 25,
#  'Afyonkarahisar': 26,
#  'Kırklareli': 27,
#  'Denizli': 28,
#  'Edirne': 29,
#  'Isparta': 30,
#  'Kütahya': 31,
#  'Osmaniye': 32,
#  'Tokat': 33}

# %%
df['City'] = df['City'].map(c)
df
# Out:
#      City  City Group  Type  P1   P2   P3   P4  P5  P6  P7  ...  P31  P32  \
# 0       0           0     1   4  5.0  4.0  4.0   2   2   5  ...    3    4
# 1       1           0     0   4  5.0  4.0  4.0   1   2   5  ...    0    0
# 2       9           1     1   2  4.0  2.0  5.0   2   3   5  ...    0    0
# 3      33           1     1   6  4.5  6.0  6.0   4   4  10  ...   12   10
# 4      18           1     1   3  4.0  3.0  4.0   2   2   5  ...    1    3
# ..    ...         ...   ...  ..  ...  ...  ...  ..  ..  ..  ...  ...  ...
# 132    15           1     0   2  3.0  3.0  5.0   4   2   4  ...    0    0
# 133     2           0     0   4  5.0  4.0  4.0   2   3   5  ...    0    0
# 134    10           1     0   3  4.0  4.0  4.0   2   3   5  ...    0    0
# 135     0           0     0   4  5.0  4.0  5.0   2   2   5  ...    0    0
# 136     0           0     0   4  5.0  3.0  5.0   2   2   5  ...    0    0
#
#      P33  P34  P35  P36  P37    revenue  month  year
# ...

# %%
f,ax = plt.subplots(figsize=(15,15))
sns.heatmap(df.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
# Out:
# <AxesSubplot:>

# %%
#There is an existance of multi collinearity between many features especially among p_i(i goes from 1 to 37) features

# %%
#Multicollinearity occurs when independent variables in a regression model are correlated.
#This correlation is a problem because independent variables should be independent
#If the degree of correlation between variables is high enough, it can cause problems when you fit the model and interpret the results

# %%
def corr(dataset,threshold):
  col_corr=set() #creates a set object
  corr_matrix=dataset.corr()#returns the correlation matrix in triplet format,name of the first variable, name of the second variable, and the correlation value of the pair
  for i in range(len(corr_matrix.columns)):
    for j in range(i):
      if abs(corr_matrix.iloc[i,j])>threshold:  #iloc () function enables us to select a particular cell of the dataset
        col_name=corr_matrix.columns[i]
        col_corr.add(col_name)
  return col_corr

# %%
corr_features=corr(df,threshold=0.9)

# %%
l=list(corr_features)
l
# Out:
# ['P35',
#  'P36',
#  'P32',
#  'P26',
#  'P12',
#  'P31',
#  'P9',
#  'P10',
#  'P18',
#  'P34',
#  'P16',
#  'P25',
#  'P13']

# %%
#There are 13 features which are highly correlated,thus drop them

# %%
df_w_o_colin=df.drop(l,axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137 entries, 0 to 136
# Data columns (total 43 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        137 non-null    int64
#  1   City Group  137 non-null    int64
#  2   Type        137 non-null    int64
#  3   P1          137 non-null    int64
#  4   P2          137 non-null    float64
#  5   P3          137 non-null    float64
#  6   P4          137 non-null    float64
#  7   P5          137 non-null    int64
#  8   P6          137 non-null    int64
#  9   P7          137 non-null    int64
#  10  P8          137 non-null    int64
#  11  P9          137 non-null    int64
#  12  P10         137 non-null    int64
#  13  P11         137 non-null    int64
#  14  P12         137 non-null    int64
#  15  P13         137 non-null    float64
#  16  P14         137 non-null    int64
#  17  P15         137 non-null    int64
#  18  P16         137 non-null    int64
# ...

# %%
#Accuracy score

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from xgboost import XGBRegressor

# %%
from sklearn.model_selection import train_test_split
x=df_w_o_colin.drop('revenue',axis=1)
y=df_w_o_colin['revenue']
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.25)

# %%
lr = LinearRegression() 
lr=lr.fit(X_train,y_train)

# %%
kn = KNeighborsRegressor()
kn.fit(X,y)
kn.score(X,y)
# Out:
# 0.33463985438975175

# %%
X = df.drop(['City','revenue','Type'],axis = 1)
y = df.revenue.apply(np.log)

# %%
lr.fit(X,y)
lr.score(X,y)
# Out:
# 0.3606478580072332

# %%
r = RandomForestRegressor(n_estimators = 150)
r.fit(X,y)
r.score(X,y)
# Out:
# 0.8809529505407615

# %%
xgb = XGBRegressor()
xgb.fit(X,y)
xgb.score(X,y)
# Out:
# 0.9999916768611875

# %%
#Highest Accuracy score is given by DecisionTreeRegressor

# %%
X_train.shape
# Out:
# (102, 29)

# %%
y_train.shape
# Out:
# (102,)

# %%
X_test.shape
# Out:
# (35, 29)

# %%
y_test.shape
# Out:
# (35,)

# %%
lr=LinearRegression().fit(X_train,y_train)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
pred = lr.predict(X_test)
ss=mean_absolute_error(y_test,pred)
s11=mean_squared_error(y_test,pred)
s22=r2_score(y_test,pred)

print("The MAE with the linear regressor is: "+str(ss))
print("The MsE with the linear regressor is: "+str(s11))
print("The R2_Score with the linear regressor is: "+str(s22))
# Out:
# The MAE with the linear regressor is: 2970425.09750696
# The MsE with the linear regressor is: 18822538925167.812
# The R2_Score with the linear regressor is: -0.5218771852302955

# %%
#The above model is without colineared features and the below one is with colineared features

# %%
lr = LinearRegression() 
lr=lr.fit(X_train,y_train)

# %%
lr=LinearRegression().fit(X_train,y_train)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
pred = lr.predict(X_test)
s=mean_absolute_error(y_test,pred)
s1=mean_squared_error(y_test,pred)
s2=r2_score(y_test,pred)

print("The MAE with the linear regressor is: "+str(s))
print("The MsE with the linear regressor is: "+str(s1))
print("The R2_Score with the linear regressor is: "+str(s2))
# Out:
# The MAE with the linear regressor is: 2970425.09750696
# The MsE with the linear regressor is: 18822538925167.812
# The R2_Score with the linear regressor is: -0.5218771852302955

# %%
rfr = RandomForestRegressor() 
rfr=rfr.fit(X_train,y_train)

# %%
pred = rfr.predict(X_test)
s=mean_absolute_error(y_test,pred)
s1=mean_squared_error(y_test,pred)
s2=r2_score(y_test,pred)

print("The MAE with the RF regressor is: "+str(s))
print("The MsE with the RF regressor is: "+str(s1))
print("The R2_Score with the RF regressor is: "+str(s2))
# Out:
# The MAE with the RF regressor is: 1834702.1885714286
# The MsE with the RF regressor is: 11739622277545.385
# The R2_Score with the RF regressor is: 0.050804815522072166

# %%
kn=KNeighborsRegressor()
kn=kn.fit(X_train,y_train)

# %%
pred = kn.predict(X_test)
s=mean_absolute_error(y_test,pred)
s1=mean_squared_error(y_test,pred)
s2=r2_score(y_test,pred)

print("The MAE with the KN regressor is: "+str(s))
print("The MsE with the KN regressor is: "+str(s1))
print("The R2_Score with the KN regressor is: "+str(s2))
# Out:
# The MAE with the KN regressor is: 2122788.9028571425
# The MsE with the KN regressor is: 13899884268461.074
# The R2_Score with the KN regressor is: -0.12386096422025616

# %%
xgb=XGBRegressor()
xgb=xgb.fit(X_train,y_train)

# %%
pred = xgb.predict(X_test)
s=mean_absolute_error(y_test,pred)
s1=mean_squared_error(y_test,pred)
s2=r2_score(y_test,pred)

print("The MAE with the XGB regressor is: "+str(s))
print("The MsE with the XGB regressor is: "+str(s1))
print("The R2_Score with the XGB regressor is: "+str(s2))
# Out:
# The MAE with the XGB regressor is: 2013115.55
# The MsE with the XGB regressor is: 13118882181103.057
# The R2_Score with the XGB regressor is: -0.060713837092888134

# %%
#Thus the R2_Score of RandomForestRegressor is: 0.06205634948736094 ,among all above discussed model,Random Forest model gives best result.

# %%
#Highest Accuracy score given by DecisionTreeRegressor has no impact on R2_Score

# %%
#DEPLOYMENT

# %%
final_model = rfr

# %%
df.columns
# Out:
# Index(['City', 'City Group', 'Type', 'P1', 'P2', 'P3', 'P4', 'P5', 'P6', 'P7',
#        'P8', 'P9', 'P10', 'P11', 'P12', 'P13', 'P14', 'P15', 'P16', 'P17',
#        'P18', 'P19', 'P20', 'P21', 'P22', 'P23', 'P24', 'P25', 'P26', 'P27',
#        'P28', 'P29', 'P30', 'P31', 'P32', 'P33', 'P34', 'P35', 'P36', 'P37',
#        'revenue', 'month', 'year'],
#       dtype='object')

# %%
pd.DataFrame(final_model)
# Out:
#                                                     0
# 0   DecisionTreeRegressor(max_features='auto', ran...
# 1   DecisionTreeRegressor(max_features='auto', ran...
# 2   DecisionTreeRegressor(max_features='auto', ran...
# 3   DecisionTreeRegressor(max_features='auto', ran...
# 4   DecisionTreeRegressor(max_features='auto', ran...
# ..                                                ...
# 95  DecisionTreeRegressor(max_features='auto', ran...
# 96  DecisionTreeRegressor(max_features='auto', ran...
# 97  DecisionTreeRegressor(max_features='auto', ran...
# 98  DecisionTreeRegressor(max_features='auto', ran...
# 99  DecisionTreeRegressor(max_features='auto', ran...
#
# [100 rows x 1 columns]
